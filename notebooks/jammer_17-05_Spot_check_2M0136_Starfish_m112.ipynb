# %% [markdown]
# # jammer
# ## 17 - More IGRINS orders
# ### Part II. Spot check the Starfish model

# %%
import pandas as pd

# %% [markdown]
# # m 112

# %%
dat = pd.read_csv('../sf/2M0136/m112/output/marley_grid/run01/spec_config.csv')

# %%
dat.head(2)
# Out:
#         data         wl  model_composite
# 0  71796.297  15980.099     70175.323694
# 1  68291.703  15980.200     70203.390467

# %%
plt.plot(dat.wl, dat.data, label='Data')
plt.plot(dat.wl, dat.model_composite, label='Model')
plt.ylim(0, 100000)
# Out:
# (0, 100000)

# %% [markdown]
# Not super convincing.
