# %% [markdown]
# Issue 21-- SpeX Prism spectrum forward model for 2M0136

# %%
import pandas as pd

# %%
dat = pd.read_csv('../sf/2M0136/SpeX/output/marley_grid/run01/spec_config.csv')

# %%
dat.head()
# Out:
#        data           wl  model_composite
# 0  0.025060  6530.729980         0.000531
# 1  0.035163  6552.780273         0.000625
# 2  0.009701  6574.720215         0.000732
# 3  0.023956  6596.590332         0.000856
# 4  0.057420  6618.369629         0.000996

# %%
plt.step(dat.wl, dat.data, 'k')
plt.step(dat.wl, dat.model_composite, 'b')
plt.ylim(0)
# Out:
# (0, 2.0)

# %%
np.log10(np.median(dat.model_composite/dat.data))
# Out:
# -1.3276780727200737

# %%
CC = np.load('../sf/2M0136/SpeX/output/marley_grid/run01/CC_new.npy')

# %%
sns.heatmap(CC, xticklabels=False, yticklabels=False)
