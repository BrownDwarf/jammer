# %% [markdown]
# # jammer
# ## 17 - More IGRINS orders
# ### Part VI. Spot check the Starfish model

# %%
import pandas as pd

# %% [markdown]
# # m 114

# %%
dat = pd.read_csv('../sf/2M0136/m114/output/marley_grid/run01/spec_config.csv')

# %%
dat.head(2)
# Out:
#         data         wl  model_composite
# 0  62711.500  15720.100     56339.830076
# 1  62136.301  15720.201     56243.878014

# %%
plt.plot(dat.wl, dat.data, label='Data')
plt.plot(dat.wl, dat.model_composite, label='Model')
plt.ylim(0, 100000)
# Out:
# (0, 100000)
