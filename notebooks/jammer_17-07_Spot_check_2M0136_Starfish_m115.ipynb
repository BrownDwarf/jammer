# %% [markdown]
# # jammer
# ## 17 - More IGRINS orders
# ### Part VII. Spot check the Starfish model

# %%
import pandas as pd

# %% [markdown]
# # m 115

# %%
dat = pd.read_csv('../sf/2M0136/m115/output/marley_grid/run01/spec_config.csv')

# %%
dat.head(2)
# Out:
#         data       wl  model_composite
# 0  59192.898  15590.1     57673.839119
# 1  64295.801  15590.2     57675.606301

# %%
plt.plot(dat.wl, dat.data, label='Data')
plt.plot(dat.wl, dat.model_composite, label='Model')
plt.ylim(0, 100000)
# Out:
# (0, 100000)

# %% [markdown]
# Neat-- pretty solid order.
