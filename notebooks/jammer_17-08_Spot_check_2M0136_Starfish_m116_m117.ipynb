# %% [markdown]
# # jammer
# ## 17 - More IGRINS orders
# ### Part VIII. Spot check the Starfish model

# %%
import pandas as pd

# %% [markdown]
# # m 116

# %%
dat = pd.read_csv('../sf/2M0136/m116/output/marley_grid/run01/spec_config.csv')

# %%
dat.head(2)
# Out:
#         data       wl  model_composite
# 0  58270.984  15445.1     55124.475239
# 1  66877.234  15445.2     55579.206539

# %%
plt.plot(dat.wl, dat.data, label='Data')
plt.plot(dat.wl, dat.model_composite, label='Model')
plt.ylim(0, 100000)
# Out:
# (0, 100000)

# %% [markdown]
# # m117

# %%
dat = pd.read_csv('../sf/2M0136/m117/output/marley_grid/run01/spec_config.csv')

# %%
plt.plot(dat.wl, dat.data, label='Data')
plt.plot(dat.wl, dat.model_composite, label='Model')
plt.ylim(0, 100000)
# Out:
# (0, 100000)

# %% [markdown]
# Another good order

# %% [markdown]
# Great order!!
