# %% [markdown]
# # jammer
# ## 17 - More IGRINS orders
# ### Part II. Spot check the Starfish model

# %%
import pandas as pd

# %% [markdown]
# # m 111

# %%
dat = pd.read_csv('../sf/2M0136/m111/output/marley_grid/run01/spec_config.csv')

# %%
dat.head(2)
# Out:
#         data       wl  model_composite
# 0  61324.699  16120.1     60371.475421
# 1  61980.301  16120.3     60733.525383

# %%
plt.plot(dat.wl, dat.data, label='Data')
plt.plot(dat.wl, dat.model_composite, label='Model')
plt.ylim(0, 100000)
# Out:
# (0, 100000)

# %% [markdown]
# Something is off with these lines, or we're making really bad model assumptions.  one of the two.

# %% [markdown]
# ### The end.
